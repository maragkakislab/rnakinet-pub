# %%
from rnamodif.evaluation.eval_vis import *

# %%
import pickle

with open('old_all_mix_preds.pkl', 'rb') as f:
    preds = pickle.load(f)
plot_roc(preds)

# %%
import pickle

with open('old_all_mix_preds.pkl', 'rb') as f:
    preds = pickle.load(f)
plot_roc(preds)

# %%
from rnamodif.architectures.rodan_pretrained_modcaller import RodanPretrainedModcaller

exp_label = {
    'm6A_0_covid':'neg', 
    'UNM_novoa_1':'neg',
    'UNM_novoa_2':'neg',
    'UNM_novoa_short':'neg',    
    'm6A_5_covid':'pos',
    'm6A_33_covid':'pos',
    'm6A_10_covid':'pos',
    'm6a_novoa_1':'pos',
    'm6a_novoa_2':'pos',
    
    # 'm5C_0_covid':'neg',
    # '5eu_2022_nia':'neg',
    # 'UNM_2022_nia':'neg',
}
pw_limit = 1000
# new_all_mix = get_dsets_preds(
#     checkpoint='/home/jovyan/RNAModif/rnamodif/checkpoints_pl/m6a_basecaller_test_mix/epoch=0-step=372000.ckpt',
#     arch=RodanPretrainedModcaller,
#     exp_label_dict = exp_label,
#     window=4096, stride = 3584, batch_size=32, workers=1, per_worker_read_limit=pw_limit, profiler=None)

# old_all_mix = get_dsets_preds(
#     checkpoint='/home/jovyan/RNAModif/rnamodif/checkpoints_pl/m6a_all_mix_deploy/last.ckpt',
#     arch=RodanPretrainedMIL,
#     exp_label_dict = exp_label,
#     window=4096, stride = 3584, batch_size=32, workers=1, per_worker_read_limit=pw_limit, profiler=None, shuffle=False)

new_tt = get_dsets_preds(
    checkpoint='/home/jovyan/RNAModif/rnamodif/checkpoints_pl/m6a_basecaller_test/epoch=0-step=154000.ckpt',
    arch=RodanPretrainedModcaller,
    exp_label_dict = exp_label,
    window=4096, stride = 4096, batch_size=32, workers=1, per_worker_read_limit=pw_limit, profiler=None, shuffle=False)
# novoa = get_dsets_preds(
#     checkpoint='/home/jovyan/RNAModif/rnamodif/checkpoints_pl/m6a_basecaller_test_novoa/epoch=0-step=147500.ckpt',
#     arch=RodanPretrainedModcaller,
#     exp_label_dict = exp_label,
#     window=4096, stride = 4096, batch_size=32, workers=1, per_worker_read_limit=pw_limit, profiler=None, shuffle=False)
# Out:
# Using 16bit native Automatic Mixed Precision (AMP)
# /home/jovyan/my-conda-envs/RNAmodEnvRod/lib/python3.8/site-packages/pytorch_lightning/loops/utilities.py:93: PossibleUserWarning: `max_epochs` was not set. Setting it to 1000 epochs. To train without an epoch limit, set `max_epochs=-1`.
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /home/jovyan/my-conda-envs/RNAmodEnvRod/lib/python3.8/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:219: PossibleUserWarning: The dataloader, predict_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 128 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Predicting: 0it [00:00, ?it/s]
# ...

# %%
# old_tt = get_dsets_preds(
#     checkpoint='/home/jovyan/RNAModif/rnamodif/checkpoints_pl/m6a_nih_33_deploy/epoch=0-step=443500.ckpt',
#     arch=RodanPretrainedMIL,
#     exp_label_dict = exp_label,
#     window=4096, stride = 4096, batch_size=32, workers=1, per_worker_read_limit=pw_limit, profiler=None, shuffle=False)

# old_nih_mix = get_dsets_preds(
#     checkpoint='/home/jovyan/RNAModif/rnamodif/checkpoints_pl/m6a_nih_mix_deploy/epoch=0-step=557500.ckpt',
#         arch=RodanPretrainedMIL,
#         exp_label_dict = exp_label,
#         window=4096, stride = 4096, batch_size=32, workers=1, per_worker_read_limit=pw_limit, profiler=None)

# old_novoa = get_dsets_preds(
#     checkpoint='/home/jovyan/RNAModif/rnamodif/checkpoints_pl/m6a_novoa_all_deploy/epoch=0-step=392000.ckpt',
#     arch=RodanPretrainedMIL,
#     exp_label_dict = exp_label,
#     window=4096, stride = 4096, batch_size=32, workers=1, per_worker_read_limit=pw_limit, profiler=None)

# %%
# old_all_mix = get_dsets_preds(
#     checkpoint='/home/jovyan/RNAModif/rnamodif/checkpoints_pl/m6a_all_mix_deploy/epoch=0-step=48000.ckpt',
#     arch=RodanPretrainedMIL,
#     exp_label_dict = exp_label,
#     window=4096, stride = 4096, batch_size=32, workers=1, per_worker_read_limit=pw_limit, profiler=None, shuffle=False)

# new_nih_mix = get_dsets_preds(
#     checkpoint='/home/jovyan/RNAModif/rnamodif/checkpoints_pl/m6a_basecaller_nih_mix/epoch=0-step=78500.ckpt',
#         arch=RodanPretrainedModcaller,
#         exp_label_dict = exp_label,
#         window=4096, stride = 4096, batch_size=32, workers=1, per_worker_read_limit=pw_limit, profiler=None)

# %%
import pickle

# with open('old_all_mix_preds.pkl', 'rb') as f:
    # old_all_mix = pickle.load(f)
# plot_roc_curves(new_all_mix, pooling='max', title='All new')
# plot_roc_curves(old_all_mix, pooling='max', title='ALL old')
# plot_roc(filter_dset_preds(old_all_mix, ['m6A_10_covid','m5C']), pooling='max', title='ALL old')



    # 'm5C_0_covid':'neg',
    # '5eu_2022_nia':'neg',
    # 'UNM_2022_nia':'neg',


# olt_tt = 0.87
# old_all_mix = 0.94

test_thresholds(new_all_mix, max_threshold=0.92)
# test_thresholds(old_all_mix, max_threshold=0.95)

# test_thresholds(old_all_mix, max_threshold=0.9)

# get_decision_points(new_all_mix, max_threshold=0.92, title='new all')
# get_decision_points(old_all_mix, max_threshold=0.92, title='old all')
# Out:
# m6A_0_covid
# max based 1.0
# m6A_5_covid
# max based 0.0
# m6A_33_covid
# max based 0.0
# m6A_10_covid
# max based 0.0
# MAX BASED ACC 0.25
# POS ACC 0.0
# NEG ACC 1.0
# -------------

# %%
from matplotlib import pyplot as plt
#new_mix = all datasets, old_mix = nih 0,5,10,33
# plot_roc_curves(new_mix, pooling='max', title='All new')
# plot_roc_curves(new_tt, pooling='max', title='33 new')
# plot_roc_curves(novoa, pooling='max', title='Novoa new')

# plot_roc_curves(old_mix, pooling='max', title='0,5,10,33 old')
plot_roc_curves(new_tt, pooling='max', title='33 old')
# plot_roc_curves(old_novoa, pooling='max', title='Novoa old')

# plot_covid_roc(new_mix, pooling='max', title='All new')
# plot_covid_roc(new_tt, pooling='max', title='33 new')
# plot_covid_roc(novoa, pooling='max', title='Novoa new')

# test_thresholds(new_mix, max_threshold=0.9)
# test_thresholds(new_tt, max_threshold=0.9)
# test_thresholds(novoa, max_threshold=0.9)

# test_thresholds(old_mix, max_threshold=0.9)
test_thresholds(new_tt, max_threshold=0.7)
# test_thresholds(old_novoa, max_threshold=0.9)


# get_decision_points(new_mix, max_threshold=0.81, title='covid')
# get_decision_points(new_tt, max_threshold=0.81, title='covid')
# get_decision_points(old_mix, max_threshold=0.81, title='covid')
# get_decision_points(old_tt, max_threshold=0.81, title='covid')
# Out:
# m6A_0_covid
# max based 0.775
# UNM_novoa_1
# max based 0.979
# UNM_novoa_2
# max based 0.983
# UNM_novoa_short
# max based 0.996
# m6A_5_covid
# max based 0.626
# m6A_33_covid
# max based 0.958
# m6A_10_covid
# max based 0.801
# m6a_novoa_1
# max based 0.074
# m6a_novoa_2
# max based 0.04
# MAX BASED ACC 0.6924444444444444
# POS ACC 0.4998
# NEG ACC 0.93325
# -------------

# %%
# plot_roc(bc_preds, pooling='max', title='All')
# plot_roc(filter_dset_preds(bc_preds, ['covid']), pooling='max', title='nia data')
# plot_roc(filter_dset_preds(bc_preds, ['novoa']), pooling='max', title='novoa data')


plot_roc_curves(bc_preds, title='All', pooling='max')
plot_roc_curves(bc_preds, title='All', pooling='mean')


plot_covid_roc(bc_preds, title='All covid data -')
plot_covid_roc(bc_preds, title='All covid data -', pooling='mean')


test_thresholds(bc_preds, max_threshold=0.85, mean_threshold=0.3)
# test_thresholds(filter_dset_preds(bc_preds,['covid']), max_threshold=0.81)

get_decision_points(bc_preds, max_threshold=0.81, title='covid')
# Out:
# m6A_0_covid
# mean based 0.189
# max based 0.864
# UNM_novoa_1
# mean based 0.987
# max based 0.975
# UNM_novoa_2
# mean based 0.94
# max based 0.977
# UNM_novoa_short
# mean based 0.988
# max based 0.996
# m6A_5_covid
# mean based 0.991
# max based 0.935
# m6A_33_covid
# mean based 0.991
# max based 0.909
# m6A_10_covid
# mean based 0.987
# max based 0.931
# m6a_novoa_1
# mean based 0.925
# max based 0.913
# m6a_novoa_2
# mean based 0.876
# max based 0.789
# MEAN BASED ACC 0.8748888888888889
# MAX BASED ACC 0.9209999999999999
# -------------

# %%
# plot_roc(bc_preds, pooling='max', title='All')
# plot_roc(filter_dset_preds(bc_preds, ['covid']), pooling='max', title='nia data')
# plot_roc(filter_dset_preds(bc_preds, ['novoa']), pooling='max', title='novoa data')


plot_roc_curves(bc_preds, title='All', pooling='max')
plot_roc_curves(bc_preds, title='All', pooling='mean')


plot_covid_roc(bc_preds, title='All covid data -')
plot_covid_roc(bc_preds, title='All covid data -', pooling='mean')


test_thresholds(bc_preds, max_threshold=0.81, mean_threshold=0.3)
# test_thresholds(filter_dset_preds(bc_preds,['covid']), max_threshold=0.81)

get_decision_points(bc_preds, max_threshold=0.81, title='covid')
# Out:
# m6A_0_covid
# mean based 0.66
# max based 0.745
# UNM_novoa_1
# mean based 0.921
# max based 0.864
# UNM_novoa_2
# mean based 0.906
# max based 0.824
# UNM_novoa_short
# mean based 0.938
# max based 0.964
# m6A_5_covid
# mean based 0.791
# max based 0.508
# m6A_33_covid
# mean based 0.967
# max based 0.95
# m6A_10_covid
# mean based 0.858
# max based 0.672
# m6a_novoa_1
# mean based 0.834
# max based 0.76
# m6a_novoa_2
# mean based 0.766
# max based 0.606
# MEAN BASED ACC 0.849
# MAX BASED ACC 0.7658888888888887
# -------------

# %%
# from rnamodif.architectures.rodan_simple import RodanSimple

# exp_label = {
#     '5eu_2022_nia':'pos',
#     '5eu_2020_nia':'pos',
#     'UNM_2022_nia':'neg',
#     'UNM_2020_nia':'neg',
#     '5eu_nanoid_24h':'pos',
#     '5eu_nanoid_1h':'pos',
#     '5eu_nanoid_mix':'pos',
#     '5eu_nanoid_neg':'neg',
# }
# feu_preds = get_dsets_preds(
#     checkpoint='/home/jovyan/RNAModif/rnamodif/checkpoints_pl/5eu_nih_light_conv/epoch=0-step=314500.ckpt',
#     arch=RodanSimple,
#     exp_label_dict = exp_label,
#     window=4096, 
#     stride = 4096, 
#     batch_size=32, 
#     workers=5, 
#     per_worker_read_limit=200, 
#     # profiler='simple'
#     trim_primer=True,
# )

# %%
# # plot_roc(feu_preds, pooling='max', title='All 5eu')
# plot_roc(filter_dset_preds(feu_preds, ['2022_nia']), pooling='max', title='nia data')
# plot_roc(filter_dset_preds(feu_preds, ['2020_nia']), pooling='max', title='nia data')
# plot_roc(filter_dset_preds(feu_preds, ['nanoid_mix','UNM_2022']), pooling='max', title='nia data')
# plot_roc(filter_dset_preds(feu_preds, ['5eu_2022','nanoid_neg']), pooling='max', title='nia data')

# %%
# get_decision_points(filter_dset_preds(feu_preds,['2020']), max_threshold=0.9, title='5eu')

# %%
# # test_thresholds(filter_dset_preds(feu_preds,['2022']), max_threshold=0.91)
# # test_thresholds(feu_preds, max_threshold=0.91)

# get_decision_points(filter_dset_preds(feu_preds,['2022']), max_threshold=0.9, title='5eu')
# # get_decision_points(filter_dset_preds(zero33_preds,['_0_covid']), max_threshold=0.91, title='covid')

# %%
from rnamodif.architectures.rodan_pretrained_MIL import RodanPretrainedMIL
from rnamodif.architectures.rodan_simple import RodanSimple

exp_label = {
    'm6A_0_covid':'neg',
    'UNM_novoa_1':'neg',
    'UNM_novoa_2':'neg',
    'UNM_novoa_short':'neg',    
    'm6A_5_covid':'pos',
    'm6A_33_covid':'pos',
    'm6A_10_covid':'pos',
    'm6a_novoa_1':'pos',
    'm6a_novoa_2':'pos',
}
pw_limit = 1000
big_preds_no = get_dsets_preds(
    checkpoint='/home/jovyan/RNAModif/rnamodif/checkpoints_pl/m6a_nih_33_deploy/epoch=0-step=443500.ckpt',
    arch=RodanPretrainedMIL,
    exp_label_dict = exp_label,
    window=4096, stride = 4096, batch_size=32, workers=1, per_worker_read_limit=pw_limit, profiler=None)

big_preds_o = get_dsets_preds(
    checkpoint='/home/jovyan/RNAModif/rnamodif/checkpoints_pl/m6a_nih_33_deploy/epoch=0-step=443500.ckpt',
    arch=RodanPretrainedMIL,
    exp_label_dict = exp_label,
    window=4096, stride = 2048, batch_size=32, workers=1, per_worker_read_limit=pw_limit, profiler=None)


# small_preds_no = get_dsets_preds(
#     checkpoint='/home/jovyan/RNAModif/rnamodif/checkpoints_pl/m6a_nih_light_conv/epoch=0-step=264500.ckpt',
#     arch=RodanSimple,
#     exp_label_dict = exp_label,
#     window=4096, stride = 4096, batch_size=32, workers=1, per_worker_read_limit=pw_limit, profiler=None)

# small_preds_o = get_dsets_preds(
#     checkpoint='/home/jovyan/RNAModif/rnamodif/checkpoints_pl/m6a_nih_light_conv/epoch=0-step=264500.ckpt',
#     arch=RodanSimple,
#     exp_label_dict = exp_label,
#     window=4096, stride = 2048, batch_size=32, workers=1, per_worker_read_limit=pw_limit, profiler=None)


#1:24 ez predict
#1:24 with workers
#1:23 big batch size 256
#1.36 small bs 8
#with stride 4096 (not 2048) 0:44 
#with precision=16 0:43
# no worker logic in dataloader  0:45
# With benchmark=true in dloader 0:44
#ddp strategy incompatible with jupyter - try it out 0:46
#light version conv = 20s
# batch size = gpu memory taken, check
#try out stride effect on AUROC
#try to run scipt if it runs the same, also workers = faster? test
# Out:
# Using 16bit native Automatic Mixed Precision (AMP)
# /home/jovyan/my-conda-envs/RNAmodEnvRod/lib/python3.8/site-packages/pytorch_lightning/loops/utilities.py:93: PossibleUserWarning: `max_epochs` was not set. Setting it to 1000 epochs. To train without an epoch limit, set `max_epochs=-1`.
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /home/jovyan/my-conda-envs/RNAmodEnvRod/lib/python3.8/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:219: PossibleUserWarning: The dataloader, predict_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 128 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Predicting: 0it [00:00, ?it/s]
# ...

# %%
big_preds_so = get_dsets_preds(
    checkpoint='/home/jovyan/RNAModif/rnamodif/checkpoints_pl/m6a_nih_33_deploy/epoch=0-step=443500.ckpt',
    arch=RodanPretrainedMIL,
    exp_label_dict = exp_label,
    window=4096, stride = 3584, batch_size=32, workers=1, per_worker_read_limit=pw_limit, profiler=None)
# Out:
# Using 16bit native Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 0it [00:00, ?it/s]
# Using 16bit native Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 0it [00:00, ?it/s]
# Using 16bit native Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 0it [00:00, ?it/s]
# Using 16bit native Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# ...

# %%
# plot_roc_curves(big_preds_no, title='All covid data -')
# plot_roc_curves(big_preds_o, title='All covid data -')
plot_roc_curves(big_preds_so, title='All covid data -')

# plot_covid_roc(big_preds_no, title='All covid data -')
# plot_covid_roc(big_preds_o, title='All covid data -')
plot_covid_roc(big_preds_so, title='All covid data -')

# test_thresholds(filter_dset_preds(big_preds_no,['covid']), max_threshold=0.89)
# test_thresholds(filter_dset_preds(big_preds_o,['covid']), max_threshold=0.91)
test_thresholds(filter_dset_preds(big_preds_so,['covid']), max_threshold=0.85)

# get_decision_points(big_preds_no, max_threshold=0.85, title='covid')
# get_decision_points(big_preds_o, max_threshold=0.85, title='covid')
get_decision_points(big_preds_so, max_threshold=0.85, title='covid')
# Out:
# m6A_0_covid
# max based 0.796
# m6A_5_covid
# max based 0.722
# m6A_33_covid
# max based 0.959
# m6A_10_covid
# max based 0.841
# MAX BASED ACC 0.8294999999999999
# -------------

# %%
test_thresholds(filter_dset_preds(big_preds_so,['novoa']), max_threshold=0.80)
test_thresholds(filter_dset_preds(big_preds_so,['novoa']), max_threshold=0.85)
test_thresholds(filter_dset_preds(big_preds_so,['novoa']), max_threshold=0.90)
# Out:
# UNM_novoa_1
# max based 0.516
# UNM_novoa_2
# max based 0.478
# UNM_novoa_short
# max based 0.945
# m6a_novoa_1
# max based 0.74
# m6a_novoa_2
# max based 0.649
# MAX BASED ACC 0.6656000000000001
# -------------
# UNM_novoa_1
# max based 0.602
# UNM_novoa_2
# max based 0.54
# UNM_novoa_short
# max based 0.967
# m6a_novoa_1
# max based 0.676
# m6a_novoa_2
# max based 0.593
# MAX BASED ACC 0.6756
# -------------
# UNM_novoa_1
# max based 0.7
# UNM_novoa_2
# max based 0.662
# UNM_novoa_short
# max based 0.987
# m6a_novoa_1
# max based 0.516
# m6a_novoa_2
# max based 0.475
# MAX BASED ACC 0.668
# -------------

# %%
import pickle
#Limited predictions
# pw_limit = 100

# mix_preds = get_dsets_preds(checkpoint='/home/jovyan/RNAModif/rnamodif/checkpoints_pl/m6a_nih_mix_deploy/epoch=0-step=557500.ckpt',
#                            window=4096, stride = 2048, batch_size=64, workers=1, per_worker_read_limit=pw_limit, profiler=None)
# zero33_preds = get_dsets_preds(checkpoint='/home/jovyan/RNAModif/rnamodif/checkpoints_pl/m6a_nih_33_deploy/epoch=0-step=443500.ckpt',
#                               window=4096, stride = 2048, batch_size=64, workers=1, per_worker_read_limit=pw_limit, profiler=None)

# novoa_preds = get_dsets_preds(checkpoint='/home/jovyan/RNAModif/rnamodif/checkpoints_pl/m6a_novoa_all_deploy/epoch=0-step=392000.ckpt',
#                               window=4096, stride = 2048, batch_size=64, workers=1, per_worker_read_limit=pw_limit, profiler=None)

# with open('mix_preds.pkl', 'wb') as f:
#     pickle.dump(mix_preds, f)
    
# with open('zero33_preds.pkl', 'wb') as f:
#     pickle.dump(zero33_preds, f)

# with open('novoa_preds.pkl', 'wb') as f:
#     pickle.dump(novoa_preds, f)
    
# with open('mix_preds.pkl', 'rb') as f:
#     mix_preds = pickle.load(f)    
    
# with open('zero33_preds.pkl', 'rb') as f:
#     zero33_preds = pickle.load(f)
    
# with open('novoa_preds.pkl', 'rb') as f:
#     novoa_preds = pickle.load(f)

# %%
plot_roc_curves(mix_preds, title='All covid data -')

# %%
# plot_roc_curves(mix_preds, title='All covid data -')
# plot_roc_curves(zero33_preds, title='0 and 33 covid data -')
# plot_roc_curves(novoa_preds, 'All novoa data -')

plot_roc_curves(m6a_preds, title='All covid data -')

# %%
plot_covid_roc(mix_preds, title='0 and 33 covid data -')

# %%
plot_covid_roc(m6a_preds, title='0 and 33 covid data -')

# %%
plot_covid_roc(mix_preds, title='All covid data -')
plot_covid_roc(zero33_preds, title='0 and 33 covid data -')
plot_covid_roc(novoa_preds, 'All novoa data -')

# %%
test_thresholds(filter_dset_preds(m6a_preds,['covid']), max_threshold=0.84)
test_thresholds(filter_dset_preds(mix_preds,['covid']), max_threshold=0.89)

test_thresholds(filter_dset_preds(m6a_preds,['novoa']), max_threshold=0.84)
test_thresholds(filter_dset_preds(mix_preds,['novoa']), max_threshold=0.89)
# Out:
# m6A_0_covid
# max based 0.822
# m6A_5_covid
# max based 0.656
# m6A_33_covid
# max based 0.962
# m6A_10_covid
# max based 0.83
# MAX BASED ACC 0.8175
# -------------
# m6A_0_covid
# max based 0.86
# m6A_5_covid
# max based 0.642
# m6A_33_covid
# max based 0.954
# m6A_10_covid
# max based 0.805
# MAX BASED ACC 0.81525
# -------------
# UNM_novoa_1
# max based 0.278
# UNM_novoa_2
# max based 0.263
# UNM_novoa_short
# max based 0.976
# m6a_novoa_1
# max based 0.756
# m6a_novoa_2
# max based 0.698
# MAX BASED ACC 0.5942
# -------------
# UNM_novoa_1
# max based 0.718
# UNM_novoa_2
# max based 0.674
# UNM_novoa_short
# max based 0.98
# m6a_novoa_1
# max based 0.529
# m6a_novoa_2
# max based 0.479
# MAX BASED ACC 0.6759999999999999
# -------------

# %%
test_thresholds(filter_dset_preds(mix_preds,['covid']), max_threshold=0.93)
test_thresholds(filter_dset_preds(mix_preds,['novoa']), max_threshold=0.93)
# Out:
# m6A_0_covid
# max based 0.91
# m6A_5_covid
# max based 0.91
# m6A_33_covid
# max based 0.89
# m6A_10_covid
# max based 0.92
# MAX BASED ACC 0.9075
# -------------
# UNM_novoa_1
# max based 0.91
# UNM_novoa_2
# max based 0.93
# UNM_novoa_short
# max based 1.0
# m6a_novoa_1
# max based 0.02
# m6a_novoa_2
# max based 0.01
# MAX BASED ACC 0.574
# -------------

# %%
test_thresholds(filter_dset_preds(zero33_preds,['covid']), max_threshold=0.91)
test_thresholds(filter_dset_preds(zero33_preds,['novoa']), max_threshold=0.91)
# Out:
# m6A_0_covid
# max based 0.82
# m6A_5_covid
# max based 0.7
# m6A_33_covid
# max based 0.95
# m6A_10_covid
# max based 0.89
# MAX BASED ACC 0.84
# -------------
# UNM_novoa_1
# max based 0.73
# UNM_novoa_2
# max based 0.64
# UNM_novoa_short
# max based 0.98
# m6a_novoa_1
# max based 0.53
# m6a_novoa_2
# max based 0.44
# MAX BASED ACC 0.6639999999999999
# -------------

# %%
test_thresholds(filter_dset_preds(novoa_preds,['covid']), max_threshold=0.85)
test_thresholds(filter_dset_preds(novoa_preds,['novoa']), max_threshold=0.85)
# Out:
# m6A_0_covid
# max based 0.69
# m6A_5_covid
# max based 0.3
# m6A_33_covid
# max based 0.46
# m6A_10_covid
# max based 0.24
# MAX BASED ACC 0.4225
# -------------
# UNM_novoa_1
# max based 0.91
# UNM_novoa_2
# max based 0.93
# UNM_novoa_short
# max based 0.98
# m6a_novoa_1
# max based 0.93
# m6a_novoa_2
# max based 0.95
# MAX BASED ACC 0.9400000000000001
# -------------

# %%
get_decision_points(m6a_preds, max_threshold=0.84, title='covid')
# get_decision_points(filter_dset_preds(m6a_preds,['_0_covid']), max_threshold=0.91, title='covid')
# get_decision_points(filter_dset_preds(m6a_preds,['_5_covid']), max_threshold=0.91, title='covid')
# get_decision_points(filter_dset_preds(m6a_preds,['_10_covid']), max_threshold=0.91, title='covid')
# get_decision_points(filter_dset_preds(m6a_preds,['_33_covid']), max_threshold=0.91, title='covid')
get_decision_points(mix_preds, max_threshold=0.89, title='covid')

# %%
get_decision_points(zero33_preds, max_threshold=0.9, title='covid')
# get_decision_points(filter_dset_preds(zero33_preds,['_0_covid']), max_threshold=0.91, title='covid')
# get_decision_points(filter_dset_preds(zero33_preds,['_5_covid']), max_threshold=0.91, title='covid')
# get_decision_points(filter_dset_preds(zero33_preds,['_10_covid']), max_threshold=0.91, title='covid')
# get_decision_points(filter_dset_preds(zero33_preds,['_33_covid']), max_threshold=0.91, title='covid')

# %%
get_decision_points(mix_preds, max_threshold=0.93, title='covid')
# get_decision_points(filter_dset_preds(mix_preds,['_0_covid']), max_threshold=0.93, title='covid')
# get_decision_points(filter_dset_preds(mix_preds,['_5_covid']), max_threshold=0.93, title='covid')
# get_decision_points(filter_dset_preds(mix_preds,['_10_covid']), max_threshold=0.93, title='covid')
# get_decision_points(filter_dset_preds(mix_preds,['_33_covid']), max_threshold=0.93, title='covid')

# %%
# get_decision_points(novoa_preds, max_threshold=0.8, title='covid')
# get_decision_points(filter_dset_preds(novoa_preds,['_0_covid']), max_threshold=0.8, title='covid')
# get_decision_points(filter_dset_preds(novoa_preds,['_5_covid']), max_threshold=0.8, title='covid')
# get_decision_points(filter_dset_preds(novoa_preds,['_10_covid']), max_threshold=0.8, title='covid')
# get_decision_points(filter_dset_preds(novoa_preds,['_33_covid']), max_threshold=0.8, title='covid')
get_decision_points(filter_dset_preds(novoa_preds,['novoa']), max_threshold=0.8, title='covid')
