# %%
from rnamodif.evaluation.eval_vis import *

# %%
from rnamodif.architectures.rodan_pretrained_MIL import RodanPretrainedMIL
from rnamodif.architectures.rodan_pretrained_modcaller import RodanPretrainedModcaller

exp_label = {
    's4U_0_covid':'neg',
    's4U_33_covid':'pos',
    's4U_5_covid':'pos',
    's4U_10_covid':'pos',
}
pw_limit = 1000
big_preds = get_dsets_preds(
    checkpoint='/home/jovyan/RNAModif/rnamodif/checkpoints_pl/s4u_0v33_big/last.ckpt',
    arch=RodanPretrainedMIL,
    exp_label_dict = exp_label,
    window=4096, stride = 4096, batch_size=32, workers=1, per_worker_read_limit=pw_limit, profiler=None, shuffle=False)

base_preds = get_dsets_preds(
    checkpoint='/home/jovyan/RNAModif/rnamodif/checkpoints_pl/s4u_0v33_base_unweighted_withNloss/last.ckpt',
    arch=RodanPretrainedModcaller,
    exp_label_dict = exp_label,
    window=4096, stride = 4096, batch_size=32, workers=1, per_worker_read_limit=pw_limit, profiler=None, shuffle=False)
# Out:
# TODO fix rodan path
# TODO fix rodan path
# Using 16bit native Automatic Mixed Precision (AMP)
# /home/jovyan/my-conda-envs/RNAmodEnvRod/lib/python3.8/site-packages/pytorch_lightning/loops/utilities.py:93: PossibleUserWarning: `max_epochs` was not set. Setting it to 1000 epochs. To train without an epoch limit, set `max_epochs=-1`.
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /home/jovyan/my-conda-envs/RNAmodEnvRod/lib/python3.8/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:219: PossibleUserWarning: The dataloader, predict_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 128 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# ...

# %%
from matplotlib import pyplot as plt
curve = 'roc'
plot_curve(filter_dset_preds(big_preds, ['_0','_33']), pooling='max', title='s4u old', curve=curve)
plot_curve(filter_dset_preds(big_preds, ['_0','_5']), pooling='max', title='s4u old', curve=curve)
plot_curve(filter_dset_preds(big_preds, ['_0','_10']), pooling='max', title='s4u old', curve=curve)

plt.show()
plot_curve(filter_dset_preds(base_preds, ['_0','_33']), pooling='max', title='s4u new', curve=curve)
plot_curve(filter_dset_preds(base_preds, ['_0','_5']), pooling='max', title='s4u new', curve=curve)
plot_curve(filter_dset_preds(base_preds, ['_0','_10']), pooling='max', title='s4u new', curve=curve)

# %%
from matplotlib import pyplot as plt
curve = 'pr'
plot_curve(filter_dset_preds(big_preds, ['_0','_33']), pooling='max', title='s4u old', curve=curve)
plot_curve(filter_dset_preds(big_preds, ['_0','_5']), pooling='max', title='s4u old', curve=curve)
plot_curve(filter_dset_preds(big_preds, ['_0','_10']), pooling='max', title='s4u old', curve=curve)

plt.show()
plot_curve(filter_dset_preds(base_preds, ['_0','_33']), pooling='max', title='s4u new', curve=curve)
plot_curve(filter_dset_preds(base_preds, ['_0','_5']), pooling='max', title='s4u new', curve=curve)
plot_curve(filter_dset_preds(base_preds, ['_0','_10']), pooling='max', title='s4u new', curve=curve)


# test_thresholds(new_tt, max_threshold=0.9)
# test_thresholds(new_tt, max_threshold=0.7)
# get_decision_points(filter_dset_preds(preds, ['2022']), max_threshold=0.91, title='2022')

# %%
get_decision_points(filter_dset_preds(big_preds, ['s4U']), max_threshold=0.91, title='covid old')

get_decision_points(filter_dset_preds(base_preds, ['s4U']), max_threshold=0.91, title='covid new')
